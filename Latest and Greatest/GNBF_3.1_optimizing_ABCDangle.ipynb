# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([
[22,	73.2],
[20,	71.5],
[18,	68.7],
[16,	64.7],
[14.25, 60.0],
[14,	59.2],
[12,    52.3]])

# %%
plt.figure()
plt.plot(data[:,0],data[:,1])
plt.grid()
plt.xlabel('ABCDangle_deg')
plt.ylabel('prism-prism angle')
# Out:
# Text(0, 0.5, 'prism-prism angle')
