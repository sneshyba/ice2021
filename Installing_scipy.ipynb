# %%
import sys

# %%
# This forces installation of an older version of scipy (seems to be needed in places in the GNBF code base)
# !{sys.executable} -m pip install "scipy==1.13.0"
# !{sys.executable} -m pip show scipy
# Out:
# ...
#   Using cached scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl (30.3 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# ...

# %%
# # This restores/upgrades scipy to the latest version
# !{sys.executable} -m pip install --upgrade scipy
# !{sys.executable} -m pip show scipy
